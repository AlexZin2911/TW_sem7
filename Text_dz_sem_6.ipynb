# %% [markdown]
# ### ***1***. Даны две  независимые выборки. Не соблюдается условие нормальности
# ### x1  380,420, 290
# ### y1 140,360,200,900
# ### Сделайте вывод по результатам, полученным с помощью функции

# %%
from scipy.stats import mannwhitneyu

x1 = [380,420,290]
y1 = [140,360,200,900]

stat, p = mannwhitneyu(x1, y1, alternative='two-sided')
alpha = 0.05

if p > alpha:
    print("Нет статистически значимых различий между выборками (p-value = {:.3f})".format(p))
else:
    print("Обнаружены статистически значимые различия между выборками (p-value = {:.3f})".format(p))
# Out:
# Нет статистически значимых различий между выборками (p-value = 0.629)

# %% [markdown]
# ### Ответ:
# ### ***Статистически заначимых различий между выбоками нет.***

# %% [markdown]
# ### ***2***.  Исследовалось влияние препарата на уровень давления пациентов. Сначала измерялось давление до приема препарата, потом через 10 минут и через 30 минут. Есть ли статистически значимые различия?
# ### 1е измерение до приема препарата: 150, 160, 165, 145, 155
# ### 2е измерение через 10 минут: 140, 155, 150,  130, 135
# ### 3е измерение через 30 минут: 130, 130, 120, 130, 125

# %%
from scipy.stats import f_oneway 

before = [150, 160, 165, 145, 155]
after_10 = [140, 155, 150, 130, 135]
after_30 = [130, 130, 120, 130, 125]

f_value, p_value = f_oneway(before, after_10, after_30)

print(f"p_value = {p_value:.5f}")

if p_value < 0.05:
    print("Различия статистически значимы")
else:
    print("Различия статистически не значимы")
# Out:
# p_value = 0.00047
# Различия статистически значимы

# %% [markdown]
# ### Ответ:
# ### ***Различия статистически значимы***

# %% [markdown]
# ### ***3***. Сравните 1 и 2 е измерения, предполагая, что 3го измерения через 30 минут не было.

# %%
from scipy.stats import ttest_ind

before = [150, 160, 165, 145, 155]
after_10 = [140, 155, 150, 130, 135]

t_value, p_value = ttest_ind(before, after_10)

print(f"p_value = {p_value:.5f}")
if p_value < 0.05:
    print("Различия в значениях первых и вторых измерений статистически значимы")
else:
    print("Различия в значениях первых и вторых измерений статистически не значимы")
# Out:
# p_value = 0.05634
# Различия в значениях первых и вторых измерений статистически не значимы

# %% [markdown]
# ### Ответ:
# ### ***Различия в значениях первых и вторых измерений статистически не значимы.***

# %% [markdown]
# ### ***4***. Даны 3 группы  учеников плавания.
# ### В 1 группе время на дистанцию 50 м составляют:
# ### 56, 60, 62, 55, 71, 67, 59, 58, 64, 67
# ### Вторая группа : 57, 58, 69, 48, 72, 70, 68, 71, 50, 53
# ### Третья группа: 57, 67, 49, 48, 47, 55, 66, 51, 54

# %%
from scipy.stats import kruskal

group1 = [56, 60, 62, 55, 71, 67, 59, 58, 64, 67]
group2 = [57, 58, 69, 48, 72, 70, 68, 71, 50, 53]
group3 = [57, 67, 49, 48, 47, 55, 66, 51, 54]

h_value, p_value = kruskal(group1, group2, group3)

print(f"p_value = {p_value:.5f}")

if p_value < 0.05:
    print("Различия статистически значимы")
else:
    print("Различия статистически не значимы")
# Out:
# p_value = 0.06504
# Различия статистически не значимы

# %% [markdown]
# ### Ответ:
# ### ***Различия статистически не значимы***

# %% [markdown]
# ### ***3.*** Заявляется, что партия изготавливается со средним арифметическим 2,5 см. Проверить данную гипотезу, если известно, что размеры изделий подчинены нормальному закону распределения. Объем выборки 10, уровень статистической значимости 5%
# ### 2.51, 2.35, 2.74, 2.56, 2.40, 2.36, 2.65, 2.7, 2.67, 2.34

# %% [markdown]
# Использую t-критерий Стьюдента.
# H0: среднее арифметическое равно 2.5.
# H1: среднее арифметическое не равно 2.5.
#
# Уровень значимости alpha = 0.05.
#
# Критические значения t-критерия Стьюдента определяются из таблицы, так как критическая область двусторонняя. Для alpha/2 = 0.025 и степеней свободы (n-1) = 9. Значение tкр = 2.262.
#
# Выборочное среднее (X) = 2.516, стандартное отклонение = 0.157.
#
# t-статистика вычисляется по формуле:
# t = (X - mu) / (s / sqrt(n)),
# t = (2.516 - 2.5) / (0.157 / sqrt(10)) = 0.95
#
# Мы не можем отвергнуть нулевую гипотезу, так как значение t = 0.95 не превышает критическое значение tкр = 2.262.

# %% [markdown]
# ### Ответ:
# ### ***Среднее арифметическое не отличается от 2.5 см, так как статистически значимых значимых оснований для этого нет.***
